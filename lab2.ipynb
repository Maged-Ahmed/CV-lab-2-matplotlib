# %% [markdown]
# <a href="https://colab.research.google.com/github/Maged-Ahmed/CV-lab-2-matplotlib/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot((1,2,3,4))

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
thing = np.arange(1,50)
plt.plot(thing)

# %%
thing2 = thing**2
plt.plot(thing2)

# %%
thingsin = np.sin(thing)
plt.plot(thingsin,'r--')

# %%
plt.axis([0,5,-1,0])
plt.title('plotted boy')
plt.plot(thingsin,'r--')

# %%
thingcos = np.cos(thing)
plt.plot(thingcos,'b--')

# %%
plt.plot(thingcos,'b--',thingsin,'r--')

# %%
plt.plot(thingcos,'b--',thingsin,'r--',linewidth = 3)

# %%
plt.subplot(211)
plt.plot(thingcos,'b--',thingsin,'r--',linewidth = 3)
plt.subplot(212)
plt.plot(thingcos,'y',thingsin,'g--',linewidth = 3)

# %%
plt.plot(thingcos,'y',thingsin,'g--',linewidth = 3)
plt.title('title')
plt.xlabel('x label')
plt.ylabel('y label')
plt.text(0,1,'text')
plt.text(10,1,'text2')
# Out:
# Text(10, 1, 'text2')

# %%
plt.plot(thingcos,'or')
plt.text(0,0.55,'point1')
plt.grid()

# %%
plt.subplot(211)
plt.plot(thingcos,'b--',thingsin,'r--',linewidth = 3)
plt.legend(['sine','cosine'])
plt.subplot(212)
plt.plot(thingcos,'y',thingsin,'g--',linewidth = 3)
plt.legend(['sine','cosine'])
plt.savefig('figure1.png')

# %%
pop = np.random.randint(0,100,100)
plt.hist(pop,bins=28)
# Out:
# (array([2., 2., 3., 1., 2., 3., 2., 4., 4., 3., 6., 8., 6., 1., 5., 2., 4.,
#         3., 3., 6., 4., 6., 2., 2., 8., 1., 2., 5.]),
#  array([ 0.        ,  3.53571429,  7.07142857, 10.60714286, 14.14285714,
#         17.67857143, 21.21428571, 24.75      , 28.28571429, 31.82142857,
#         35.35714286, 38.89285714, 42.42857143, 45.96428571, 49.5       ,
#         53.03571429, 56.57142857, 60.10714286, 63.64285714, 67.17857143,
#         70.71428571, 74.25      , 77.78571429, 81.32142857, 84.85714286,
#         88.39285714, 91.92857143, 95.46428571, 99.        ]),
#  <BarContainer object of 28 artists>)

# %%
index = [0,1,2,3,4]
values = [3,5,7,2,6]
plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['sky','pyramid','shaded pyramid']
vales = [80,10,10]
colors = ['blue','yellow','brown']
plt.pie(vales, labels = labels, colors = colors)
plt.axis('equal')
# Out:
# (-1.1000000056491936,
#  1.100000010561534,
#  -1.100000007859747,
#  1.1000000029474057)

# %%
xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)
fig,ax=plt.subplots(1,1)
cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
#ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection ='3d')

# %%
x = np.outer(np.linspace(-2, 2, 50), np.ones(50))
y = x.copy().T
z = np.cos(x ** 2 + y ** 3)
 
fig = plt.figure()
 
# syntax for 3-D plotting
ax = plt.axes(projection ='3d')
 
# syntax for plotting
ax.plot_surface(x, y, z, cmap ='viridis', edgecolor ='green')
ax.set_title('Surface plot')
plt.show()

# %%
x = np.random.randint(30,40,100)
y = np.random.randint(30,40,100)
z = np.random.randint(30,40,100)


fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x, y, z, color = "blue")
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()
